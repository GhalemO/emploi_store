# %%
import requests
import json
import numpy
from pandas.io.json import json_normalize
from pymongo import MongoClient
import time
client = MongoClient("mongodb+srv://BuckZ:max@idedata-xucf1.gcp.mongodb.net/test")
db = client.emploistore
offres = db.offres
offres.find_one()

# API CONNECTION #

client_id="PAR_idedataskills_ff9af1db81dd556671117874e2785cfb7744be3b25148a472f2d29a5b00b4126" # Your API ID Here
client_secret="ea2d066069be79cec2299c0b1081063c7a070b531d36ec6fd7144b74f6ddd5ae" # Your API Secret Here
response=requests.post(
    "https://entreprise.pole-emploi.fr/connexion/oauth2/access_token",
    data={
        'grant_type': 'client_credentials',
        'client_id': client_id,
        'client_secret': client_secret,
        'scope':'api_offresdemploiv1 o2dsoffre application_{}'.format(client_id),
        'realm':'partenaire'
    },
    headers={'Content-Type':'application/x-www-form-urlencoded','Accept':'application/json'}
    , params={"technicalParameters":{"page":1}}
).json()
token=response['access_token']

# %%
#Initialisation de la liste des départements
listdept= [i for i in range(1,96) if i!=20] 
listdept.extend(["2A","2B",971,972,973,974,976])
for i,j in enumerate(listdept[0:9]):
    listdept[i]=str(0)+str(j)

# %%
for iteration in listdept:    
    #  REQUEST API  #

    url='https://api.emploi-store.fr/partenaire/offresdemploi/v1/rechercheroffres'
    arguments = {"criterias":{"departmentCode": "{}".format(iteration), "keywords":"Développeur"}}
    result=requests.post(url,
                         params={"technicalParameters":{"page":1}},
        headers={'Authorization': 'Bearer {}'.format(token),'Content-Type':'application/json','Accept':'application/json'        
                },     
                json=arguments)
    time.sleep(2)
    data = json.loads(result.text) 
        
    #EXTRACT USEFUL DATA FROM JSON AND INSERT TO MONGO #

    list_dico = []
    for item in data['results']:
        tempo_dict = {}
        list_skill = []
        try:
            tempo_dict.update({'companyContactEmail' : item['companyContactEmail']})
            tempo_dict.update({'companyDescription' : item['companyDescription'].replace("\n", '')})
            tempo_dict.update({'companyWorkforceName' : item['companyWorkforceName']})
            tempo_dict.update({'departmentCode' : item['departmentCode']})
            tempo_dict.update({'description' : item['description'].replace("\n", '')})
            tempo_dict.update({'romeProfessionCode' : item['romeProfessionCode']})
            tempo_dict.update({'romeProfessionName' : item['romeProfessionName']})
            tempo_dict.update({'title' : item['title']})
            tempo_dict.update({'minSalary' : item['minSalary']})
            tempo_dict.update({'maxSalary' : item['maxSalary']})
            for skill in item['skills']:
                list_skill.append(skill['skillName'])
                tempo_dict.update({'skills' : list_skill})
            offres.insert_one(tempo_dict)
        except KeyError:
            pass

# %%
len(data['results'])
# Out:
# 115

# %%
test = offres.aggregate([{"$project":{"title":1, "maxSalary":1}}])

# %%
test.next()
# Out:
# {'_id': ObjectId('5b46157ad52340662e742745'),
#  'maxSalary': 48000.0,
#  'title': 'Développeur / Développeuse Sénior Python (H/F)'}

# %%
url='https://api.emploi-store.fr/partenaire/offresdemploi/v1/rechercheroffres'
arguments = {"criterias":{"departmentCode": "90", "keywords":"Boulanger"}}
result=requests.post(url,
                         params={"technicalParameters":{"page":1}},
        headers={'Authorization': 'Bearer {}'.format(token),'Content-Type':'application/json','Accept':'application/json'        
                },     
                json=arguments)

data = json.loads(result.text)

# %%
data
# Out:
# {'results': [{'activityCode': '47',
#    'activityName': 'Commerce de détail de pain, pâtisserie et confiserie en magasin spécialisé',
#    'cityCode': '90032',
#    'cityName': 'DANJOUTIN',
#    'companyContactEmail': 'blachere-49042@candidatus.com',
#    'companyDescription': "Marie Blachère est une enseigne de boulangerie traditionnelle avec une fabrication sur place tout au long de la journée. Le concept créé en 2004, est basé sur la fraîcheur et des offres promotionnelles attractives toute l'année.",
#    'companyModalityInterviewCode': 'MEL',
#    'companyModalityInterviewName': 'Envoyer votre CV par mail',
#    'companyName': 'BOULANGERIE DE MARIE BLACHERE',
#    'companyUrl': 'http://www.marieblachere.com',
#    'companyWorkforceCode': '12',
#    'companyWorkforceName': '20 à 49 salariés',
#    'contactDetails1': 'Courriel : blachere-49042@candidatus.com',
#    'contactName': 'BOULANGERIE DE MARIE BLACHERE - M. Le responsable',
#    'continentCode': '9C',
#    'continentName': 'EUROPE',
#    'contractNatureCode': 'E1',
#    'contractNatureName': 'Contrat travail',
#    'contractTypeCode': 'CDI',
#    'contractTypeName': 'Contrat à durée indéterminée',
#    'countryCode': 'FR',
#    'countryName': 'FRANCE',
#    'creationDate': '2018-07-13T00:00:00+02:00',
#    'degrees': [{'degreeCode': '21538',
#      'degreeComment': 'boulangerie ou grande distribution',
#      'degreeName': 'Boulangerie',
#      'degreeTypeCode': 'NV5',
#      'degreeTypeName': 'CAP, BEP ou équivalent',
#      'requiredDegreeCode': 'S',
#      'requiredDegreeName': 'Souhaité'},
#     {'degreeCode': '99999',
#      'degreeComment': 'Pas de commentaire formation',
#      'degreeName': 'Information non communiquée',
#      'degreeTypeName': 'Pas de libelle niveau de formation'}],
#    'departmentCode': '90',
#    'departmentName': 'TERRITOIRE DE BELFORT',
#    'description': 'Le boulanger a pour mission de réaliser la fabrication des produits mis en vente.\n- Il contribue à assurer le bon fonctionnement quotidien et la qualité des produits mis en vente dans le respect des recettes.\n- Il garantit la réalisation des missions qui lui sont confiées par le Responsable Production. Poste à pourvoir rapidement.',
#    'desktops': [],
#    'drivingLicenses': [],
#    'experienceCode': 'D',
#    'experienceName': 'Débutant accepté',
#    'gpsLatitude': 47.61777778,
#    'gpsLongitude': 6.863888888,
#    'isDisabledAccessibility': 0,
#    'isPartTimeWorking': 0,
#    'isWorkAlternately': 0,
#    'languages': [],
#    'logoSociety': 'Dpyd0DLEuzFqZdtfYCbh4yFLUcp2XYsQ',
#    'minSalary': 1498.5,
#    'modificationDate': '2018-07-13T00:00:00+02:00',
#    'numberMonthSalary': 12.0,
#    'numberVacancies': 1,
#    'offerId': '074RXCK',
#    'originCode': '0',
#    'originName': 'PE',
#    'origins': [{'originCode': 'PE',
#      'originName': 'Pôle emploi',
#      'originUrl': 'https://candidat.pole-emploi.fr/offres/recherche/detail/074RXCK'}],
#    'postcode': '90400',
#    'preselectionCode': 'A',
#    'preselectionName': 'Absence de présélection',
#    'professionalQualities': [{'professionalQualityCode': '3',
#      'professionalQualityName': 'Travail en équipe'},
#     {'professionalQualityCode': '8',
#      'professionalQualityName': 'Sens de l’organisation'},
#     {'professionalQualityCode': '14',
#      'professionalQualityName': 'Réactivité'}],
#    'qualificationCode': '2',
#    'regionCode': '27',
#    'regionName': 'BOURGOGNE-FRANCHE-COMTE',
#    'romeProfessionCode': '11573',
#    'romeProfessionName': 'Boulanger / Boulangère',
#    'salary1Comment': 'Mutuelle',
#    'salary2Comment': 'CE',
#    'salaryCode': 'M',
#    'salaryCurrencyCode': 'EUR',
#    'salaryCurrencyName': 'Euros',
#    'salaryName': 'Mensuel',
#    'score': 100,
#    'skills': [{'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '124929',
#      'skillName': 'Boulage des pâtons',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '126290',
#      'skillName': 'Bouler et effectuer la tourne ou le façonnage des pâtons',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '119368',
#      'skillName': 'Conduire une fermentation',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '124928',
#      'skillName': 'Diviser la masse de pâte en pâtons',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '101738',
#      'skillName': "Sélectionner et doser les ingrédients (farine, levure, additifs, ...) pour la réalisation des pâtes à pain ou à viennoiserie, les mélanger et effectuer le pétrissage, l'abaisse",
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'}],
#    'subContinentCode': '9A',
#    'subContinentName': 'EUROPE HORS CEE',
#    'title': 'Boulanger / Boulangère H/F',
#    'weeklyWorkTime': '35H',
#    'weeklyWorkTimeTypeCode': 'TLS',
#    'weeklyWorkTimeTypeName': 'Travail le samedi'},
#   {'activityCode': '78',
#    'activityName': 'Activités des agences de travail temporaire',
#    'cityCode': '90010',
#    'cityName': 'BELFORT',
#    'companyContactEmail': 'agence@celtis.eu',
#    'companyDescription': 'Celtis Travail Temporaire\n14 rue Frédéric Japy\n25 200 MONTBELIARD\n\n0381710070',
#    'companyModalityInterviewCode': 'MEL',
#    'companyModalityInterviewName': 'Envoyer votre CV par mail',
#    'companyName': 'CELTIS',
#    'companyUrl': 'www.celtis.eu',
#    'companyWorkforceCode': '0',
#    'companyWorkforceName': '0 salarié',
#    'contactDetails1': 'Courriel : agence@celtis.eu',
#    'contactName': 'CELTIS - Mme Anais Vincenzi',
#    'continentCode': '9C',
#    'continentName': 'EUROPE',
#    'contractDuration': 6,
#    'contractDurationUnitCode': 'MO',
#    'contractDurationUnitName': 'Mois',
#    'contractNatureCode': 'E1',
#    'contractNatureName': 'Contrat travail',
#    'contractTypeCode': 'MIS',
#    'contractTypeName': 'Travail intérimaire',
#    'countryCode': 'FR',
#    'countryName': 'FRANCE',
#    'creationDate': '2018-07-11T00:00:00+02:00',
#    'degrees': [{'degreeCode': '21538',
#      'degreeComment': 'Pas de commentaire formation',
#      'degreeName': 'Boulangerie',
#      'degreeTypeCode': 'NV5',
#      'degreeTypeName': 'CAP, BEP ou équivalent',
#      'requiredDegreeCode': 'S',
#      'requiredDegreeName': 'Souhaité'},
#     {'degreeCode': '99999',
#      'degreeComment': 'Pas de commentaire formation',
#      'degreeName': 'Information non communiquée',
#      'degreeTypeName': 'Pas de libelle niveau de formation'}],
#    'departmentCode': '90',
#    'departmentName': 'TERRITOIRE DE BELFORT',
#    'description': "Nous recherchons pour notre client des boulangers\nVous êtes autonome\nVous préparez et réalisez des produits de boulangerie et de viennoiserie selon les règles d'hygiène et de sécurité alimentaires.\nVous effectuer la vente de produits de boulangerie, viennoiserie.\n\nTravail d'équipe (tournée) \n13eme mois, participation et intéressement \n",
#    'desktops': [],
#    'drivingLicenses': [],
#    'experienceCode': 'D',
#    'experienceName': 'Débutant accepté',
#    'gpsLatitude': 47.6375,
#    'gpsLongitude': 6.862777777,
#    'isDisabledAccessibility': 0,
#    'isPartTimeWorking': 0,
#    'isWorkAlternately': 0,
#    'languages': [],
#    'logoSociety': '0b0aba3c2d724721b369c5f0d76a0a77',
#    'maxSalary': 11.0,
#    'minSalary': 9.88,
#    'modificationDate': '2018-07-16T00:00:00+02:00',
#    'numberMonthSalary': 12.0,
#    'numberVacancies': 2,
#    'offerId': '074PDMY',
#    'originCode': '0',
#    'originName': 'PE',
#    'origins': [{'originCode': 'PE',
#      'originName': 'Pôle emploi',
#      'originUrl': 'https://candidat.pole-emploi.fr/offres/recherche/detail/074PDMY'}],
#    'postcode': '90000',
#    'preselectionCode': 'A',
#    'preselectionName': 'Absence de présélection',
#    'professionalQualities': [{'professionalQualityCode': '5',
#      'professionalQualityName': 'Sens de la communication'},
#     {'professionalQualityCode': '6', 'professionalQualityName': 'Autonomie'},
#     {'professionalQualityCode': '12',
#      'professionalQualityName': 'Persévérance'}],
#    'qualificationCode': '3',
#    'regionCode': '27',
#    'regionName': 'BOURGOGNE-FRANCHE-COMTE',
#    'romeProfessionCode': '11573',
#    'romeProfessionName': 'Boulanger / Boulangère',
#    'salaryCode': 'H',
#    'salaryCurrencyCode': 'EUR',
#    'salaryCurrencyName': 'Euros',
#    'salaryName': 'Horaire',
#    'score': 100,
#    'skills': [{'requiredSkillCode': 'E',
#      'requiredSkillName': 'Exigé',
#      'skillCode': '126290',
#      'skillName': 'Bouler et effectuer la tourne ou le façonnage des pâtons',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'E',
#      'requiredSkillName': 'Exigé',
#      'skillCode': '124928',
#      'skillName': 'Diviser la masse de pâte en pâtons',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'E',
#      'requiredSkillName': 'Exigé',
#      'skillCode': '101738',
#      'skillName': "Sélectionner et doser les ingrédients (farine, levure, additifs, ...) pour la réalisation des pâtes à pain ou à viennoiserie, les mélanger et effectuer le pétrissage, l'abaisse",
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '124929',
#      'skillName': 'Boulage des pâtons',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '119368',
#      'skillName': 'Conduire une fermentation',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'}],
#    'subContinentCode': '9A',
#    'subContinentName': 'EUROPE HORS CEE',
#    'title': 'Boulanger / Boulangère',
#    'weeklyWorkTime': '35H',
#    'weeklyWorkTimeTypeCode': 'NOR',
#    'weeklyWorkTimeTypeName': 'Horaires normaux'},
#   {'activityCode': '10',
#    'activityName': 'Boulangerie et boulangerie-pâtisserie',
#    'cityCode': '90010',
#    'cityName': 'BELFORT',
#    'companyContactEmail': 'blachere-98331@candidatus.com',
#    'companyDescription': "Marie Blachère est une enseigne de boulangerie traditionnelle avec une fabrication sur place tout au long de la journée. Le concept créé en 2004, est basé sur la fraîcheur et des offres promotionnelles attractives toute l'année.",
#    'companyModalityInterviewCode': 'MEL',
#    'companyModalityInterviewName': 'Envoyer votre CV par mail',
#    'companyName': 'BOULANGERIE MARIE BLACHERE',
#    'companyUrl': 'http://www.marieblachere.com',
#    'companyWorkforceCode': '12',
#    'companyWorkforceName': '20 à 49 salariés',
#    'contactDetails1': 'Courriel : blachere-98331@candidatus.com',
#    'contactName': 'BOULANGERIE MARIE BLACHERE - M. responsable Le',
#    'continentCode': '9C',
#    'continentName': 'EUROPE',
#    'contractNatureCode': 'E1',
#    'contractNatureName': 'Contrat travail',
#    'contractTypeCode': 'CDI',
#    'contractTypeName': 'Contrat à durée indéterminée',
#    'countryCode': 'FR',
#    'countryName': 'FRANCE',
#    'creationDate': '2018-07-05T00:00:00+02:00',
#    'degrees': [{'degreeCode': '21538',
#      'degreeComment': 'Boulangerie ou grande distribution',
#      'degreeName': 'Boulangerie',
#      'degreeTypeCode': 'NV4',
#      'degreeTypeName': 'Bac ou équivalent',
#      'requiredDegreeCode': 'S',
#      'requiredDegreeName': 'Souhaité'},
#     {'degreeCode': '99999',
#      'degreeComment': 'Pas de commentaire formation',
#      'degreeName': 'Information non communiquée',
#      'degreeTypeName': 'Pas de libelle niveau de formation'}],
#    'departmentCode': '90',
#    'departmentName': 'TERRITOIRE DE BELFORT',
#    'description': 'Le Responsable Production a pour mission de superviser, coordonner, réaliser et contrôler la fabrication des produits mis en vente.\n- Il contribue à assurer le bon fonctionnement quotidien et la qualité du travail dans les laboratoires dans le respect des méthodes et des procédures établies par la Direction dans tous les domaines.\n- Il garantit la réalisation des missions et tâches qui lui sont confiées par le Responsable de magasin ou le Responsable Magasin Adjoint.\n- Il est responsable du travail des employés du laboratoire.',
#    'desktops': [],
#    'drivingLicenses': [],
#    'experienceDuration': '2',
#    'experienceDurationUnitName': 'ans',
#    'gpsLatitude': 47.6375,
#    'gpsLongitude': 6.862777777,
#    'isDisabledAccessibility': 0,
#    'isPartTimeWorking': 0,
#    'isWorkAlternately': 0,
#    'languages': [],
#    'minSalary': 2096.29,
#    'modificationDate': '2018-07-09T00:00:00+02:00',
#    'numberMonthSalary': 12.0,
#    'numberVacancies': 1,
#    'offerId': '074HNLF',
#    'originCode': '0',
#    'originName': 'PE',
#    'origins': [{'originCode': 'PE',
#      'originName': 'Pôle emploi',
#      'originUrl': 'https://candidat.pole-emploi.fr/offres/recherche/detail/074HNLF'}],
#    'postcode': '90000',
#    'preselectionCode': 'A',
#    'preselectionName': 'Absence de présélection',
#    'professionalQualities': [],
#    'qualificationCode': '8',
#    'regionCode': '27',
#    'regionName': 'BOURGOGNE-FRANCHE-COMTE',
#    'romeProfessionCode': '12006',
#    'romeProfessionName': 'Chef boulanger / boulangère',
#    'salary1Comment': 'Primes',
#    'salary2Comment': 'Mutuelle',
#    'salaryCode': 'M',
#    'salaryCurrencyCode': 'EUR',
#    'salaryCurrencyName': 'Euros',
#    'salaryName': 'Mensuel',
#    'score': 100,
#    'skills': [],
#    'subContinentCode': '9A',
#    'subContinentName': 'EUROPE HORS CEE',
#    'title': 'Chef boulanger / boulangère',
#    'weeklyWorkTime': '39H',
#    'weeklyWorkTimeTypeCode': 'TLS',
#    'weeklyWorkTimeTypeName': 'Travail le samedi'},
#   {'activityCode': '10',
#    'activityName': 'Boulangerie et boulangerie-pâtisserie',
#    'cityCode': '90010',
#    'cityName': 'BELFORT',
#    'companyContactEmail': 'blachere-98256@candidatus.com',
#    'companyDescription': "Marie Blachère est une enseigne de boulangerie traditionnelle avec une fabrication sur place tout au long de la journée. Le concept créé en 2004, est basé sur la fraîcheur et des offres promotionnelles attractives toute l'année.",
#    'companyModalityInterviewCode': 'MEL',
#    'companyModalityInterviewName': 'Envoyer votre CV par mail',
#    'companyName': 'BOULANGERIE MARIE BLACHERE',
#    'companyUrl': 'http://www.marieblachere.com',
#    'companyWorkforceCode': '12',
#    'companyWorkforceName': '20 à 49 salariés',
#    'contactComment': 'blachere-59710@candidatus.com',
#    'contactDetails1': 'Courriel : blachere-98256@candidatus.com',
#    'contactName': 'BOULANGERIE MARIE BLACHERE - M. Le responsable',
#    'continentCode': '9C',
#    'continentName': 'EUROPE',
#    'contractNatureCode': 'E1',
#    'contractNatureName': 'Contrat travail',
#    'contractTypeCode': 'CDI',
#    'contractTypeName': 'Contrat à durée indéterminée',
#    'countryCode': 'FR',
#    'countryName': 'FRANCE',
#    'creationDate': '2018-07-05T00:00:00+02:00',
#    'degrees': [{'degreeCode': '21528',
#      'degreeComment': 'Boulangerie ou restauration',
#      'degreeName': 'Pâtisserie',
#      'degreeTypeCode': 'NV5',
#      'degreeTypeName': 'CAP, BEP ou équivalent',
#      'requiredDegreeCode': 'S',
#      'requiredDegreeName': 'Souhaité'},
#     {'degreeCode': '21538',
#      'degreeComment': 'Boulangerie ou grande distribution',
#      'degreeName': 'Boulangerie',
#      'degreeTypeCode': 'NV5',
#      'degreeTypeName': 'CAP, BEP ou équivalent',
#      'requiredDegreeCode': 'S',
#      'requiredDegreeName': 'Souhaité'}],
#    'departmentCode': '90',
#    'departmentName': 'TERRITOIRE DE BELFORT',
#    'description': 'Le préparateur a pour mission de préparer la viennoiserie, les produits salés et sucrés mis en vente.\n- Il contribue à assurer le bon fonctionnement quotidien et la qualité des produits mis en vente dans le respect des recettes, des process établis par la Direction.\n- Il garantit la réalisation des missions et tâches qui lui sont confiées par le Responsable Production Adjoint ou le Responsable Production.',
#    'desktops': [],
#    'drivingLicenses': [],
#    'experienceDuration': '6',
#    'experienceDurationUnitCode': 'MO',
#    'experienceDurationUnitName': 'mois',
#    'gpsLatitude': 47.6375,
#    'gpsLongitude': 6.862777777,
#    'isDisabledAccessibility': 0,
#    'isPartTimeWorking': 0,
#    'isWorkAlternately': 0,
#    'languages': [],
#    'minSalary': 1498.47,
#    'modificationDate': '2018-07-09T00:00:00+02:00',
#    'numberMonthSalary': 12.0,
#    'numberVacancies': 2,
#    'offerId': '074HMPS',
#    'originCode': '0',
#    'originName': 'PE',
#    'origins': [{'originCode': 'PE',
#      'originName': 'Pôle emploi',
#      'originUrl': 'https://candidat.pole-emploi.fr/offres/recherche/detail/074HMPS'}],
#    'postcode': '90000',
#    'preselectionCode': 'A',
#    'preselectionName': 'Absence de présélection',
#    'professionalQualities': [{'professionalQualityCode': '3',
#      'professionalQualityName': 'Travail en équipe'},
#     {'professionalQualityCode': '8',
#      'professionalQualityName': 'Sens de l’organisation'},
#     {'professionalQualityCode': '14',
#      'professionalQualityName': 'Réactivité'}],
#    'qualificationCode': '5',
#    'regionCode': '27',
#    'regionName': 'BOURGOGNE-FRANCHE-COMTE',
#    'romeProfessionCode': '11573',
#    'romeProfessionName': 'Boulanger / Boulangère',
#    'salaryCode': 'M',
#    'salaryCurrencyCode': 'EUR',
#    'salaryCurrencyName': 'Euros',
#    'salaryName': 'Mensuel',
#    'score': 100,
#    'skills': [{'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '101743',
#      'skillName': 'Calcul de quantité',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '124959',
#      'skillName': 'Cuire des pièces de viennoiserie',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '124548',
#      'skillName': 'Entretenir un poste de travail',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '124966',
#      'skillName': 'Préparer des sandwichs',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '100359',
#      'skillName': "Règles d'hygiène et de sécurité alimentaire",
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'}],
#    'subContinentCode': '9A',
#    'subContinentName': 'EUROPE HORS CEE',
#    'title': 'Préparateur / Préparatrice en boulangerie (H/F)',
#    'weeklyWorkTime': '35H',
#    'weeklyWorkTimeTypeCode': 'TLS',
#    'weeklyWorkTimeTypeName': 'Travail le samedi'},
#   {'activityCode': '10',
#    'activityName': 'Boulangerie et boulangerie-pâtisserie',
#    'cityCode': '90010',
#    'cityName': 'BELFORT',
#    'companyContactEmail': 'blachere-98281@candidatus.com',
#    'companyDescription': "Marie Blachère est une enseigne de boulangerie traditionnelle avec une fabrication sur place tout au long de la journée. Le concept créé en 2004, est basé sur la fraîcheur et des offres promotionnelles attractives toute l'année.",
#    'companyModalityInterviewCode': 'MEL',
#    'companyModalityInterviewName': 'Envoyer votre CV par mail',
#    'companyName': 'BOULANGERIE MARIE BLACHERE',
#    'companyUrl': 'http://www.marieblachere.com',
#    'companyWorkforceCode': '12',
#    'companyWorkforceName': '20 à 49 salariés',
#    'contactDetails1': 'Courriel : blachere-98281@candidatus.com',
#    'contactName': 'BOULANGERIE MARIE BLACHERE - M. Le responsable',
#    'continentCode': '9C',
#    'continentName': 'EUROPE',
#    'contractNatureCode': 'E1',
#    'contractNatureName': 'Contrat travail',
#    'contractTypeCode': 'CDI',
#    'contractTypeName': 'Contrat à durée indéterminée',
#    'countryCode': 'FR',
#    'countryName': 'FRANCE',
#    'creationDate': '2018-07-05T00:00:00+02:00',
#    'degrees': [{'degreeCode': '21538',
#      'degreeComment': 'Boulangerie ou grande distribution',
#      'degreeName': 'Boulangerie',
#      'degreeTypeCode': 'NV5',
#      'degreeTypeName': 'CAP, BEP ou équivalent',
#      'requiredDegreeCode': 'S',
#      'requiredDegreeName': 'Souhaité'},
#     {'degreeCode': '99999',
#      'degreeComment': 'Pas de commentaire formation',
#      'degreeName': 'Information non communiquée',
#      'degreeTypeName': 'Pas de libelle niveau de formation'}],
#    'departmentCode': '90',
#    'departmentName': 'TERRITOIRE DE BELFORT',
#    'description': 'Le boulanger a pour mission de réaliser la fabrication des produits mis en vente.\n- Il contribue à assurer le bon fonctionnement quotidien et la qualité des produits mis en vente dans le respect des recettes, des process et des procédures établies par la Direction.\n- Il garantit la réalisation des missions et tâches qui lui sont confiées par le Responsable Production Adjoint ou le Responsable Production.',
#    'desktops': [],
#    'drivingLicenses': [],
#    'experienceCode': 'D',
#    'experienceName': 'Débutant accepté',
#    'gpsLatitude': 47.6375,
#    'gpsLongitude': 6.862777777,
#    'isDisabledAccessibility': 0,
#    'isPartTimeWorking': 0,
#    'isWorkAlternately': 0,
#    'languages': [],
#    'minSalary': 1498.5,
#    'modificationDate': '2018-07-13T00:00:00+02:00',
#    'numberMonthSalary': 12.0,
#    'numberVacancies': 2,
#    'offerId': '074HLYM',
#    'originCode': '0',
#    'originName': 'PE',
#    'origins': [{'originCode': 'PE',
#      'originName': 'Pôle emploi',
#      'originUrl': 'https://candidat.pole-emploi.fr/offres/recherche/detail/074HLYM'}],
#    'postcode': '90000',
#    'preselectionCode': 'A',
#    'preselectionName': 'Absence de présélection',
#    'professionalQualities': [{'professionalQualityCode': '3',
#      'professionalQualityName': 'Travail en équipe'},
#     {'professionalQualityCode': '6', 'professionalQualityName': 'Autonomie'},
#     {'professionalQualityCode': '14',
#      'professionalQualityName': 'Réactivité'}],
#    'qualificationCode': '2',
#    'regionCode': '27',
#    'regionName': 'BOURGOGNE-FRANCHE-COMTE',
#    'romeProfessionCode': '11573',
#    'romeProfessionName': 'Boulanger / Boulangère',
#    'salary1Comment': 'Mutuelle',
#    'salary2Comment': 'CE',
#    'salaryCode': 'M',
#    'salaryCurrencyCode': 'EUR',
#    'salaryCurrencyName': 'Euros',
#    'salaryName': 'Mensuel',
#    'score': 100,
#    'skills': [{'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '124929',
#      'skillName': 'Boulage des pâtons',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '126290',
#      'skillName': 'Bouler et effectuer la tourne ou le façonnage des pâtons',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '119368',
#      'skillName': 'Conduire une fermentation',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '124928',
#      'skillName': 'Diviser la masse de pâte en pâtons',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '101738',
#      'skillName': "Sélectionner et doser les ingrédients (farine, levure, additifs, ...) pour la réalisation des pâtes à pain ou à viennoiserie, les mélanger et effectuer le pétrissage, l'abaisse",
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'}],
#    'subContinentCode': '9A',
#    'subContinentName': 'EUROPE HORS CEE',
#    'title': 'Boulanger / Boulangère',
#    'weeklyWorkTime': '35H',
#    'weeklyWorkTimeTypeCode': 'TLS',
#    'weeklyWorkTimeTypeName': 'Travail le samedi'},
#   {'activityCode': '10',
#    'activityName': 'Boulangerie et boulangerie-pâtisserie',
#    'agencyModalityInterviewCode': 'ACV',
#    'agencyModalityInterviewName': 'Par courrier postal',
#    'cityCode': '90010',
#    'cityName': 'BELFORT',
#    'companyModalityInterviewCode': 'ECV',
#    'companyModalityInterviewName': 'Envoyer votre CV',
#    'companyName': 'LA ROSERAIE',
#    'companyWorkforceCode': '3',
#    'companyWorkforceName': '6 à 9 salariés',
#    'contactDetails1': '14 RUE THIERS',
#    'contactDetails2': '90000 BELFORT',
#    'contactName': 'Pôle Emploi BELFORT THIERS',
#    'continentCode': '9C',
#    'continentName': 'EUROPE',
#    'contractNatureCode': 'E1',
#    'contractNatureName': 'Contrat travail',
#    'contractTypeCode': 'CDI',
#    'contractTypeName': 'Contrat à durée indéterminée',
#    'countryCode': 'FR',
#    'countryName': 'FRANCE',
#    'creationDate': '2018-07-03T00:00:00+02:00',
#    'degrees': [{'degreeCode': '99999',
#      'degreeComment': 'Pas de commentaire formation',
#      'degreeName': 'Information non communiquée',
#      'degreeTypeName': 'Pas de libelle niveau de formation'},
#     {'degreeCode': '99999',
#      'degreeComment': 'Pas de commentaire formation',
#      'degreeName': 'Information non communiquée',
#      'degreeTypeName': 'Pas de libelle niveau de formation'}],
#    'departmentCode': '90',
#    'departmentName': 'TERRITOIRE DE BELFORT',
#    'description': "Vous serez en charge de la production des produits en boulangerie, viennoiserie selon les réglés d'hygiene et de sécurité alimentaires. Travail sur four traditionnel. Vous êtes autonome sur le poste. ",
#    'desktops': [],
#    'drivingLicenses': [],
#    'experienceCode': 'D',
#    'experienceName': 'Débutant accepté',
#    'gpsLatitude': 47.6375,
#    'gpsLongitude': 6.862777777,
#    'isDisabledAccessibility': 0,
#    'isPartTimeWorking': 0,
#    'isWorkAlternately': 0,
#    'languages': [],
#    'modificationDate': '2018-07-17T00:00:00+02:00',
#    'numberVacancies': 1,
#    'offerId': '074DBDF',
#    'originCode': '0',
#    'originName': 'PE',
#    'origins': [{'originCode': 'PE',
#      'originName': 'Pôle emploi',
#      'originUrl': 'https://candidat.pole-emploi.fr/offres/recherche/detail/074DBDF'}],
#    'postcode': '90000',
#    'preselectionCode': 'C',
#    'preselectionName': 'Critère de présélection',
#    'professionalQualities': [],
#    'qualificationCode': '6',
#    'regionCode': '27',
#    'regionName': 'BOURGOGNE-FRANCHE-COMTE',
#    'romeProfessionCode': '11573',
#    'romeProfessionName': 'Boulanger / Boulangère',
#    'salary1Comment': 'A definir selon profils',
#    'salaryComment': 'A definir selon profils',
#    'score': 100,
#    'skills': [{'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '124929',
#      'skillName': 'Boulage des pâtons',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '126290',
#      'skillName': 'Bouler et effectuer la tourne ou le façonnage des pâtons',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '101743',
#      'skillName': 'Calcul de quantité',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '101748',
#      'skillName': 'Caractéristiques des farines',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '119368',
#      'skillName': 'Conduire une fermentation',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '126357',
#      'skillName': 'Confectionner des viennoiseries',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '101744',
#      'skillName': "Conversion d'unités de mesure",
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '124958',
#      'skillName': 'Cuire des pâtons',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '124959',
#      'skillName': 'Cuire des pièces de viennoiserie',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '124943',
#      'skillName': 'Décorer des produits culinaires',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '124960',
#      'skillName': 'Défourner des pains et viennoiseries',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '124928',
#      'skillName': 'Diviser la masse de pâte en pâtons',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '124545',
#      'skillName': 'Entretenir un espace de vente',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '124548',
#      'skillName': 'Entretenir un poste de travail',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '124547',
#      'skillName': 'Nettoyer du matériel ou un équipement',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '101746',
#      'skillName': 'Pétrissage manuel',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '118366',
#      'skillName': 'Produits de boulangerie',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '100359',
#      'skillName': "Règles d'hygiène et de sécurité alimentaire",
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '101738',
#      'skillName': "Sélectionner et doser les ingrédients (farine, levure, additifs, ...) pour la réalisation des pâtes à pain ou à viennoiserie, les mélanger et effectuer le pétrissage, l'abaisse",
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '101745',
#      'skillName': 'Tourage de pâte',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '100259',
#      'skillName': 'Utilisation de matériel de nettoyage',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '101747',
#      'skillName': 'Utilisation de pétrin mécanique',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'}],
#    'subContinentCode': '9A',
#    'subContinentName': 'EUROPE HORS CEE',
#    'title': 'Boulanger / Boulangère',
#    'travelFrequencyCode': '1',
#    'travelFrequencyName': 'Jamais',
#    'weeklyWorkTime': '39H',
#    'weeklyWorkTimeTypeCode': 'NOR',
#    'weeklyWorkTimeTypeName': 'Horaires normaux'},
#   {'activityCode': '47',
#    'activityName': 'Commerce de détail de pain, pâtisserie et confiserie en magasin spécialisé',
#    'cityCode': '90032',
#    'cityName': 'DANJOUTIN',
#    'companyContactEmail': 'blachere-97661@candidatus.com',
#    'companyDescription': "Marie Blachère est une enseigne de boulangerie traditionnelle avec une fabrication sur place tout au long de la journée. Le concept créé en 2004, est basé sur la fraîcheur et des offres promotionnelles attractives toute l'année.",
#    'companyModalityInterviewCode': 'MEL',
#    'companyModalityInterviewName': 'Envoyer votre CV par mail',
#    'companyName': 'BOULANGERIE DE MARIE BLACHERE',
#    'companyUrl': 'http://www.marieblachere.com',
#    'companyWorkforceCode': '12',
#    'companyWorkforceName': '20 à 49 salariés',
#    'contactDetails1': 'Courriel : blachere-97661@candidatus.com',
#    'contactName': 'BOULANGERIE DE MARIE BLACHERE - M. Le responsable',
#    'continentCode': '9C',
#    'continentName': 'EUROPE',
#    'contractDuration': 24,
#    'contractDurationUnitCode': 'MO',
#    'contractDurationUnitName': 'Mois',
#    'contractNatureCode': 'E2',
#    'contractNatureName': 'Contrat apprentissage',
#    'contractTypeCode': 'CDD',
#    'contractTypeName': 'Contrat à durée déterminée',
#    'countryCode': 'FR',
#    'countryName': 'FRANCE',
#    'creationDate': '2018-07-02T00:00:00+02:00',
#    'degrees': [{'degreeCode': '99999',
#      'degreeComment': 'Pas de commentaire formation',
#      'degreeName': 'Information non communiquée',
#      'degreeTypeName': 'Pas de libelle niveau de formation'},
#     {'degreeCode': '99999',
#      'degreeComment': 'Pas de commentaire formation',
#      'degreeName': 'Information non communiquée',
#      'degreeTypeName': 'Pas de libelle niveau de formation'}],
#    'departmentCode': '90',
#    'departmentName': 'TERRITOIRE DE BELFORT',
#    'description': "L'apprenti boulanger (H/F) a pour mission de réaliser la fabrication des produits mis en vente.\n- Il contribue à assurer le bon fonctionnement quotidien et la qualité des produits mis en vente dans le respect des recettes.\n- Il réalise des missions qui lui sont confiées par le Responsable Production.",
#    'desktops': [],
#    'drivingLicenses': [],
#    'experienceCode': 'D',
#    'experienceName': 'Débutant accepté',
#    'gpsLatitude': 47.61777778,
#    'gpsLongitude': 6.863888888,
#    'isDisabledAccessibility': 0,
#    'isPartTimeWorking': 0,
#    'isWorkAlternately': 1,
#    'languages': [],
#    'logoSociety': 'Dpyd0DLEuzFqZdtfYCbh4yFLUcp2XYsQ',
#    'modificationDate': '2018-07-13T00:00:00+02:00',
#    'numberVacancies': 1,
#    'offerId': '074CQQV',
#    'originCode': '0',
#    'originName': 'PE',
#    'origins': [{'originCode': 'PE',
#      'originName': 'Pôle emploi',
#      'originUrl': 'https://candidat.pole-emploi.fr/offres/recherche/detail/074CQQV'}],
#    'postcode': '90400',
#    'preselectionCode': 'A',
#    'preselectionName': 'Absence de présélection',
#    'professionalQualities': [{'professionalQualityCode': '3',
#      'professionalQualityName': 'Travail en équipe'},
#     {'professionalQualityCode': '8',
#      'professionalQualityName': 'Sens de l’organisation'},
#     {'professionalQualityCode': '14',
#      'professionalQualityName': 'Réactivité'}],
#    'qualificationCode': '5',
#    'regionCode': '27',
#    'regionName': 'BOURGOGNE-FRANCHE-COMTE',
#    'romeProfessionCode': '11573',
#    'romeProfessionName': 'Boulanger / Boulangère',
#    'salary1Comment': '% Smic selon âge',
#    'salaryComment': '% Smic selon âge',
#    'score': 100,
#    'skills': [],
#    'subContinentCode': '9A',
#    'subContinentName': 'EUROPE HORS CEE',
#    'title': 'CAP Boulanger / Boulangère (H/F)',
#    'weeklyWorkTime': '35H',
#    'weeklyWorkTimeTypeCode': 'NOR',
#    'weeklyWorkTimeTypeName': 'Horaires normaux'},
#   {'activityCode': '47',
#    'activityName': 'Hypermarchés',
#    'agencyModalityInterviewCode': 'TCD',
#    'agencyModalityInterviewName': 'Par courrier électronique',
#    'cityCode': '90001',
#    'cityName': 'ANDELNANS',
#    'companyModalityInterviewCode': 'MEL',
#    'companyModalityInterviewName': 'Envoyer votre CV par mail',
#    'companyWorkforceCode': '32',
#    'companyWorkforceName': '250 à 499 salariés',
#    'continentCode': '9C',
#    'continentName': 'EUROPE',
#    'contractNatureCode': 'E1',
#    'contractNatureName': 'Contrat travail',
#    'contractTypeCode': 'CDI',
#    'contractTypeName': 'Contrat à durée indéterminée',
#    'countryCode': 'FR',
#    'countryName': 'FRANCE',
#    'creationDate': '2018-06-29T00:00:00+02:00',
#    'degrees': [{'degreeCode': '21538',
#      'degreeComment': 'Pas de commentaire formation',
#      'degreeName': 'Boulangerie',
#      'degreeTypeCode': 'NV5',
#      'degreeTypeName': 'CAP, BEP ou équivalent',
#      'requiredDegreeCode': 'E',
#      'requiredDegreeName': 'Exigé'},
#     {'degreeCode': '99999',
#      'degreeComment': 'Pas de commentaire formation',
#      'degreeName': 'Information non communiquée',
#      'degreeTypeName': 'Pas de libelle niveau de formation'}],
#    'departmentCode': '90',
#    'departmentName': 'TERRITOIRE DE BELFORT',
#    'description': 'Vous êtes diplômé(e) et qualifié(e) en boulangerie. \nPour ce poste à temps plein à pourvoir rapidement  vous êtes nécessairement : \n- polyvalent(e) , rapide en exécution et autonome dans votre organisation de travail\nVous aimez le travail en équipe et vous avez le sens de la relation client car occasionnellement vous serez en contact avec la clientèle,\nVous êtes en capacité de vous adapter aux différentes réalisations et commandes.\n\nHoraires selon planning tournant (soit du matin, soit soir). 35H pointées, toute heure supplémentaire est comptabilisée.\nSalaire + 13eme mois + participation + CE',
#    'desktops': [],
#    'drivingLicenses': [],
#    'experienceCode': 'D',
#    'experienceName': 'Débutant accepté',
#    'gpsLatitude': 47.6025,
#    'gpsLongitude': 6.86861111,
#    'isDisabledAccessibility': 0,
#    'isPartTimeWorking': 0,
#    'isWorkAlternately': 0,
#    'languages': [],
#    'minSalary': 9.88,
#    'modificationDate': '2018-07-10T00:00:00+02:00',
#    'numberVacancies': 1,
#    'offerId': '073ZNRT',
#    'originCode': '0',
#    'originName': 'PE',
#    'origins': [{'originCode': 'PE',
#      'originName': 'Pôle emploi',
#      'originUrl': 'https://candidat.pole-emploi.fr/offres/recherche/detail/073ZNRT'}],
#    'postcode': '90400',
#    'preselectionCode': 'C',
#    'preselectionName': 'Critère de présélection',
#    'professionalQualities': [{'professionalQualityCode': '1',
#      'professionalQualityName': 'Capacité d’adaptation'},
#     {'professionalQualityCode': '3',
#      'professionalQualityName': 'Travail en équipe'},
#     {'professionalQualityCode': '6', 'professionalQualityName': 'Autonomie'}],
#    'qualificationCode': '3',
#    'regionCode': '27',
#    'regionName': 'BOURGOGNE-FRANCHE-COMTE',
#    'romeProfessionCode': '11573',
#    'romeProfessionName': 'Boulanger / Boulangère',
#    'salary1Comment': 'Primes',
#    'salary2Comment': '13ème mois',
#    'salaryCode': 'H',
#    'salaryComment': '13ème mois',
#    'salaryCurrencyCode': 'EUR',
#    'salaryCurrencyName': 'Euros',
#    'salaryName': 'Horaire',
#    'score': 100,
#    'skills': [{'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '124929',
#      'skillName': 'Boulage des pâtons',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '126290',
#      'skillName': 'Bouler et effectuer la tourne ou le façonnage des pâtons',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '119368',
#      'skillName': 'Conduire une fermentation',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '124928',
#      'skillName': 'Diviser la masse de pâte en pâtons',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '101738',
#      'skillName': "Sélectionner et doser les ingrédients (farine, levure, additifs, ...) pour la réalisation des pâtes à pain ou à viennoiserie, les mélanger et effectuer le pétrissage, l'abaisse",
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'}],
#    'subContinentCode': '9A',
#    'subContinentName': 'EUROPE HORS CEE',
#    'title': 'Boulanger / Boulangère',
#    'weeklyWorkTime': '35H',
#    'weeklyWorkTimeTypeCode': 'NOR',
#    'weeklyWorkTimeTypeName': 'Horaires normaux'},
#   {'activityCode': '47',
#    'activityName': 'Commerce de détail de pain, pâtisserie et confiserie en magasin spécialisé',
#    'cityCode': '90010',
#    'cityName': 'BELFORT',
#    'companyContactEmail': 'blachere-81237@candidatus.com',
#    'companyDescription': "Marie Blachère est une enseigne de boulangerie traditionnelle avec une fabrication sur place tout au long de la journée. Le concept créé en 2004, est basé sur la fraîcheur et des offres promotionnelles attractives toute l'année.",
#    'companyModalityInterviewCode': 'MEL',
#    'companyModalityInterviewName': 'Envoyer votre CV par mail',
#    'companyName': 'BOULANGERIE DE MARIE BLACHERE',
#    'companyUrl': 'www.marieblachere.com',
#    'companyWorkforceCode': '12',
#    'companyWorkforceName': '20 à 49 salariés',
#    'contactDetails1': 'Courriel : blachere-81237@candidatus.com',
#    'contactName': 'BOULANGERIE DE MARIE BLACHERE - M. Le responsable',
#    'continentCode': '9C',
#    'continentName': 'EUROPE',
#    'contractNatureCode': 'E1',
#    'contractNatureName': 'Contrat travail',
#    'contractTypeCode': 'CDI',
#    'contractTypeName': 'Contrat à durée indéterminée',
#    'countryCode': 'FR',
#    'countryName': 'FRANCE',
#    'creationDate': '2018-06-22T00:00:00+02:00',
#    'degrees': [{'degreeCode': '21538',
#      'degreeComment': 'boulangerie ou grande distribution',
#      'degreeName': 'Boulangerie',
#      'degreeTypeCode': 'NV5',
#      'degreeTypeName': 'CAP, BEP ou équivalent',
#      'requiredDegreeCode': 'S',
#      'requiredDegreeName': 'Souhaité'},
#     {'degreeCode': '99999',
#      'degreeComment': 'Pas de commentaire formation',
#      'degreeName': 'Information non communiquée',
#      'degreeTypeName': 'Pas de libelle niveau de formation'}],
#    'departmentCode': '90',
#    'departmentName': 'TERRITOIRE DE BELFORT',
#    'description': 'Le Responsable Production a pour mission de superviser, coordonner, réaliser et contrôler la\nfabrication des produits mis en vente.\n- Il contribue à assurer le bon fonctionnement quotidien et la qualité du travail dans les\nlaboratoires dans le respect des méthodes et des procédures établies par la Direction dans tous les domaines.\n- Il garantit la réalisation des missions et tâches qui lui sont confiées par le Responsable de magasin ou le Responsable Magasin Adjoint.\n- Il est responsable du travail des employés du laboratoire. Poste à pourvoir rapidement.\n',
#    'desktops': [],
#    'drivingLicenses': [],
#    'experienceDuration': '2',
#    'experienceDurationUnitName': 'ans',
#    'gpsLatitude': 47.6375,
#    'gpsLongitude': 6.862777777,
#    'isDisabledAccessibility': 0,
#    'isPartTimeWorking': 0,
#    'isWorkAlternately': 0,
#    'languages': [],
#    'logoSociety': 'Dpyd0DLEuzFqZdtfYCbh4yFLUcp2XYsQ',
#    'minSalary': 2096.29,
#    'modificationDate': '2018-07-09T00:00:00+02:00',
#    'numberMonthSalary': 12.0,
#    'numberVacancies': 1,
#    'offerId': '073QVSM',
#    'originCode': '0',
#    'originName': 'PE',
#    'origins': [{'originCode': 'PE',
#      'originName': 'Pôle emploi',
#      'originUrl': 'https://candidat.pole-emploi.fr/offres/recherche/detail/073QVSM'}],
#    'postcode': '90000',
#    'preselectionCode': 'A',
#    'preselectionName': 'Absence de présélection',
#    'professionalQualities': [{'professionalQualityCode': '3',
#      'professionalQualityName': 'Travail en équipe'},
#     {'professionalQualityCode': '8',
#      'professionalQualityName': 'Sens de l’organisation'},
#     {'professionalQualityCode': '14',
#      'professionalQualityName': 'Réactivité'}],
#    'qualificationCode': '8',
#    'regionCode': '27',
#    'regionName': 'BOURGOGNE-FRANCHE-COMTE',
#    'romeProfessionCode': '12006',
#    'romeProfessionName': 'Chef boulanger / boulangère',
#    'salary1Comment': 'Primes',
#    'salary2Comment': 'Mutuelle',
#    'salaryCode': 'M',
#    'salaryCurrencyCode': 'EUR',
#    'salaryCurrencyName': 'Euros',
#    'salaryName': 'Mensuel',
#    'score': 100,
#    'skills': [{'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '124929',
#      'skillName': 'Boulage des pâtons',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '119368',
#      'skillName': 'Conduire une fermentation',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '124959',
#      'skillName': 'Cuire des pièces de viennoiserie',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '124928',
#      'skillName': 'Diviser la masse de pâte en pâtons',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'S',
#      'requiredSkillName': 'Souhaité',
#      'skillCode': '101738',
#      'skillName': "Sélectionner et doser les ingrédients (farine, levure, additifs, ...) pour la réalisation des pâtes à pain ou à viennoiserie, les mélanger et effectuer le pétrissage, l'abaisse",
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'}],
#    'subContinentCode': '9A',
#    'subContinentName': 'EUROPE HORS CEE',
#    'title': 'Chef boulanger / boulangère',
#    'weeklyWorkTime': '39H',
#    'weeklyWorkTimeTypeCode': 'TLS',
#    'weeklyWorkTimeTypeName': 'Travail le samedi'},
#   {'activityCode': '47',
#    'activityName': 'Hypermarchés',
#    'cityCode': '90010',
#    'cityName': 'BELFORT',
#    'companyDescription': 'E.LECLERC',
#    'companyModalityInterviewCode': 'MEL',
#    'companyModalityInterviewName': 'Envoyer votre CV par mail',
#    'companyName': 'CENTRE E. LECLERC',
#    'companyWorkforceCode': '31',
#    'companyWorkforceName': '200 à 249 salariés',
#    'continentCode': '9C',
#    'continentName': 'EUROPE',
#    'contractNatureCode': 'E1',
#    'contractNatureName': 'Contrat travail',
#    'contractTypeCode': 'CDI',
#    'contractTypeName': 'Contrat à durée indéterminée',
#    'countryCode': 'FR',
#    'countryName': 'FRANCE',
#    'creationDate': '2018-06-18T00:00:00+02:00',
#    'degrees': [{'degreeCode': '99999',
#      'degreeComment': 'Pas de commentaire formation',
#      'degreeName': 'Information non communiquée',
#      'degreeTypeName': 'Pas de libelle niveau de formation'},
#     {'degreeCode': '99999',
#      'degreeComment': 'Pas de commentaire formation',
#      'degreeName': 'Information non communiquée',
#      'degreeTypeName': 'Pas de libelle niveau de formation'}],
#    'departmentCode': '90',
#    'departmentName': 'TERRITOIRE DE BELFORT',
#    'description': "Notre hypermarché E.LECLERC de Belfort recherche un(e) boulanger(ère) à temps plein sous Contrat à Durée Indéterminée. \n\nSous la responsabilité de votre responsable, vous aurez en charge l'exécution de toutes les tâches nécessaires à la fabrication des produits proposés en rayon dans le respect des règles d'hygiène et de sécurité.\n\nAinsi, vous participerez à la production ou à la préparation de produits alimentaires destinés à la consommation dans le rayon boulangerie.\n\nVous opèrerez manuellement sur les produits ou avec un outillage mécanisé. Vous exécuterez des tâches précises tout en respectant un plan de travail, des techniques particulières ou des recettes.\n\nVous devrez maîtriser les spécificités des produits que vous transformerez (mode de conservation des produits, la traçabilité, etc...).",
#    'desktops': [],
#    'drivingLicenses': [],
#    'experienceDuration': '1',
#    'experienceDurationUnitName': 'an',
#    'gpsLatitude': 47.6375,
#    'gpsLongitude': 6.862777777,
#    'isDisabledAccessibility': 0,
#    'isPartTimeWorking': 0,
#    'isWorkAlternately': 0,
#    'languages': [],
#    'logoSociety': '8d6aa3cc81684bf3bfd78d302c210bd3',
#    'modificationDate': '2018-07-13T00:00:00+02:00',
#    'numberVacancies': 1,
#    'offerId': '073JDPZ',
#    'originCode': '0',
#    'originName': 'PE',
#    'origins': [{'originCode': 'PE',
#      'originName': 'Pôle emploi',
#      'originUrl': 'https://candidat.pole-emploi.fr/offres/recherche/detail/073JDPZ'}],
#    'postcode': '90000',
#    'preselectionCode': 'A',
#    'preselectionName': 'Absence de présélection',
#    'professionalQualities': [{'professionalQualityCode': '3',
#      'professionalQualityName': 'Travail en équipe'},
#     {'professionalQualityCode': '6', 'professionalQualityName': 'Autonomie'},
#     {'professionalQualityCode': '9', 'professionalQualityName': 'Rigueur'}],
#    'qualificationCode': '6',
#    'regionCode': '27',
#    'regionName': 'BOURGOGNE-FRANCHE-COMTE',
#    'romeProfessionCode': '11573',
#    'romeProfessionName': 'Boulanger / Boulangère',
#    'salary1Comment': 'à définir',
#    'salaryComment': 'à définir',
#    'score': 100,
#    'skills': [{'requiredSkillCode': 'E',
#      'requiredSkillName': 'Exigé',
#      'skillCode': '124929',
#      'skillName': 'Boulage des pâtons',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'E',
#      'requiredSkillName': 'Exigé',
#      'skillCode': '126290',
#      'skillName': 'Bouler et effectuer la tourne ou le façonnage des pâtons',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'E',
#      'requiredSkillName': 'Exigé',
#      'skillCode': '119368',
#      'skillName': 'Conduire une fermentation',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'E',
#      'requiredSkillName': 'Exigé',
#      'skillCode': '124928',
#      'skillName': 'Diviser la masse de pâte en pâtons',
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'},
#     {'requiredSkillCode': 'E',
#      'requiredSkillName': 'Exigé',
#      'skillCode': '101738',
#      'skillName': "Sélectionner et doser les ingrédients (farine, levure, additifs, ...) pour la réalisation des pâtes à pain ou à viennoiserie, les mélanger et effectuer le pétrissage, l'abaisse",
#      'skillTypeCode': 'S',
#      'skillTypeName': 'Structurée'}],
#    'subContinentCode': '9A',
#    'subContinentName': 'EUROPE HORS CEE',
#    'title': 'Boulanger / Boulangère',
#    'weeklyWorkTime': '35H',
#    'weeklyWorkTimeTypeCode': 'NOR',
#    'weeklyWorkTimeTypeName': 'Horaires normaux'}],
#  'technicalParameters': {'endResults': 10,
#   'startResults': 1,
#   'totalNumber': 10}}

# %%
cursor  = offres.find()

# %%
cursor.next()
# Out:
# {'_id': ObjectId('5b4de5abd523400d55f44b4e'),
#  'companyContactEmail': 'offre26531412.8@gel-groupe.contactrh.com',
#  'companyDescription': "La société D2LGroup est devenu en quelques années le spécialiste des services innovants dans le secteur des ressources humaines.Poursuivant sa dynamique de croissance, D2L Group recherche aujourd'hui des Développeurs PHP / MySql.",
#  'companyWorkforceName': '0 salarié',
#  'departmentCode': '01',
#  'description': "Rattaché au service IT, localisé au siège à Saint-André-de-Corcy (01390), vous participerez au développement des applications du système d'information.Idéalement de formation Bac +2 à Bac +5, vous justifiez d'une expérience de 3 ans minimum en développement PHP / MySQL.Vous avez les compétences suivantes :- Connaissances SQL (notamment MySql)- Programmation orientée objet- PHP 5/7- Technologies Front (HTML 5, CSS 3, Javascript, Bootstrap, JQuery)Des connaissances dans le développement d'applications natives IOS ou Android est un plus.Au-delà de vos compétences, vous êtes rapidement autonome et vous tenez au courant des nouvelles tendances technologiques, ce qui vous permet d'être force de proposition.",
#  'maxSalary': 2500.0,
#  'minSalary': 2000.0,
#  'romeProfessionCode': '14153',
#  'romeProfessionName': 'Développeur / Développeuse informatique',
#  'skills': ['Analyser les besoins du client',
#   'Concevoir et développer les programmes et applications informatiques',
#   'Déterminer des mesures correctives',
#   'Etablir un cahier des charges',
#   'Rédiger une Spécification Technique de Besoin (STB)'],
#  'title': 'Développeur / Développeuse informatique'}

# %%
offres.find_one({"departmentCode":"45"})
# Out:
# {'_id': ObjectId('5b4e04bcd523400d55f453fc'),
#  'companyContactEmail': 'dsi@univ-orleans.fr',
#  'companyDescription': "L'université d'Orléans se caractérise par sa pluridisciplinarité. Elle compte 3 UFR Collegium, 1 école d'ingénieurs universitaire (Polytech Orléans), 4 Instituts Universitaires de Technologie, 1 ESPE Centre Val de Loire et l'Observatoire des Sciences de l'Univers du Centre (OSUC).Près de 16 000 étudiants, dont plus de 2 000 étudiants étrangers, fréquentent un des sites de l'université.",
#  'companyWorkforceName': '200 à 249 salariés',
#  'departmentCode': '45',
#  'description': "Le/la développeur/euse d'applications analyse, réalise et met en place des logiciels. Il définit les moyens matériels et logiciels en concertation avec le/la responsable du service.   Il/elle assure la maintenance corrective et évolutive des applications.-\tAssurer le développement des applications JavaEE, PL/SQL et PHP, de la conception jusqu'à l'intégration dans l'environnement existant -\tAssurer les tests techniques, mettre en production et organiser la recette-\tRédiger et actualiser la documentation technique et utilisateur-\tSuivre et maintenir les applications. Garantir la performance de celles-ci-\tAssurer le support de niveau 2-\tContribuer à l'enrichissement de l'équipe en partageant vos connaissances",
#  'maxSalary': 2561.0,
#  'minSalary': 2560.0,
#  'romeProfessionCode': '14148',
#  'romeProfessionName': "Développeur / Développeuse d'application",
#  'skills': ['bonnes connaissances systèmes Apache, lynux ...',
#   'Maitrise langage PL/SQL, java EE, PHP',
#   'Analyser des problèmes techniques',
#   'Concevoir et développer les programmes et applications informatiques',
#   'Déterminer des mesures correctives'],
#  'title': "Développeur / Développeuse d'application H/F (H/F)"}

# %%
offres.find_one()
